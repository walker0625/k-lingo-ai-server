# %%
from db.model.user import User
from sqlmodel import create_engine, Session, select
from db.model.interview import Interview, UserInterview
from db.model.user_store import UserCharacter
from db.model.character import Character
# from typing import TYPE_CHECKING

# %%
DATABASE_URL="postgresql://klingo:klingo@100.100.53.32:5432/k-lingo"
engine = create_engine(DATABASE_URL)
with Session(engine) as session:
    statement = select(User).where(User.id == 1)
    user = session.exec(statement).first()
    print(user)
    interviews = []
    for user_interview in user.user_interview:
        interviews.append(user_interview.interview)
    for interview in interviews:
        print(interview.kor)
# Out:
# username='d01' password='$argon2id$v=19$m=65536,t=3,p=4$BgBgzLk3JsS4956Tck7p/Q$m9c7OnTBlTnlV3nZGwnwQU5xQzWJeT2W+TpKLyD9TtY' created_at=datetime.datetime(2025, 11, 28, 15, 46, 28, 996814) id=1 fullname='d01@klingo.com' is_active=True updated_at=datetime.datetime(2025, 11, 28, 15, 46, 28, 997010)
# 고향은 어디입니까?
# 오늘은 며칠입니까?
# 소지하신 여권의 종류는 무엇입니까?
# 오늘은 무슨 요일입니까?
# 지금 어디에 살고 있습니까?
# 본국 내 영구 주소를 말씀해 주십시오.
# 가족이 모두 몇 명입니까?
# 밤 몇 시에 잡니까?
# 학교(회사)에 어떻게 옵니까?
# 이름이 무엇입니까?
# 가장 유명한 한국의 전통 음식 이름은 무엇입니까?
# 한국 내 연락 가능한 전화번호를 말씀해 주십시오.
# 여권의 만료일은 언제까지입니까?
# 성별이 어떻게 되십니까?
# 좋아하는 가수가 누구입니까?
# 생일이 언제입니까?
# 연락처 주인분과의 관계는 무엇입니까?
# 결혼 여부를 확인하겠습니다.
# 비상 연락처의 이름을 알려주십시오.
# 아침에 무엇을 먹었습니까?
