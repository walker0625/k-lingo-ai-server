# %%
from api.speaking.speaking_service import SpeakingService

service = SpeakingService()
response = service.generate_speaking_problem(1, [1,2,3,4,5])
print(response)
# Out:
# Device set to use cuda:0
# 오디오 파일 저장 완료: C:\walker\code\k-lingo-ai-server\static\audios\51e206aa-9d48-4843-b165-d2f4be3fc98e.wav
# Processed: 성(Family Name)을 말씀해 주십시오.
# 오디오 파일 저장 완료: C:\walker\code\k-lingo-ai-server\static\audios\4ab60d4c-4e1c-4f47-b128-34368576b4ab.wav
# Processed: 이름(Given Name)을 말씀해 주십시오.
# 오디오 파일 저장 완료: C:\walker\code\k-lingo-ai-server\static\audios\09fb3ac5-d194-4b3c-bba9-b51a963c6b40.wav
# Processed: 국적은 어디십니까?
# 오디오 파일 저장 완료: C:\walker\code\k-lingo-ai-server\static\audios\fdb3c1c9-6c70-4ce1-b09f-3fe840698c9a.wav
# Processed: 여권의 만료일은 언제까지입니까?
# 오디오 파일 저장 완료: C:\walker\code\k-lingo-ai-server\static\audios\97483d1f-b141-461d-8f62-284c2511f15d.wav
# Processed: 생년월일이 어떻게 되십니까?
# {"user_id": 1, "audio": [{"kor": "성(Family Name)을 말씀해 주십시오.", "eng": "Write your Family Name in Korean.", "pronunciation": "seong-(-F-a-m-i-l-y N-a-m-e-)-eul mal-sseum-hae ju-sip-si-o-.", "base64": "..."}, {"kor": "이름(Given Name)을 말씀해 주십시오.", "eng": "Please state your Given Name in Korean.", "pronunciation": "i-reum-(-G-i-v-e-n N-a-m-e-)-eul mal-sseum-hae ju-sip-si-o-.", "base64": "..."}, {"kor": "국적은 어디십니까?", "eng": "What is your nationality?", "pronunciation": "guk-jeok-eun eo-di-sip-ni-kka-?", "base64": "..."}, {"kor": "여권의 만료일은 언제까지입니까?", "eng": "What is your passport expiration date?", "pronunciation": "yeo-gwon-ui man-ryo-il-eun eon-je-kka-ji-ip-ni-kka-?", "base64": "..."}, {"kor": "생년월일이 어떻게 되십니까?", "eng": "What is your date of birth?", "pronunciation": "saeng-nyeon-wol-il-i eo-tteot-ge doe-sip-ni-kka-?", "base64": "..."}]}
